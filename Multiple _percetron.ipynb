# %%
import tensorflow as tf
from tensorflow.keras import layers, models, Sequential

# Define the MLP model
def create_mlp(input_size, hidden_sizes, output_size):
    model = models.Sequential()
    model.add(layers.InputLayer(input_shape=(input_size,)))
    
    for hidden_size in hidden_sizes:
        model.add(layers.Dense(hidden_size, activation='relu'))
    
    model.add(layers.Dense(output_size, activation='softmax'))
    
    return model

# Example usage
if __name__ == "__main__":
    # Define the model architecture for the first MLP
    input_size_1 = 10
    hidden_sizes_1 = [64, 32]
    output_size_1 = 2
    
    # Create the first MLP model
    mlp_model1 = create_mlp(input_size_1, hidden_sizes_1, output_size_1)
    
    # Display the first model summary
    mlp_model1.summary()
    print("\n\n")

    # Define the model architecture for the second MLP
    input_size_2 = 20
    hidden_sizes_2 = [74, 52]
    output_size_2 = 2
    
    # Create the second MLP model
    mlp_model2 = create_mlp(input_size_2, hidden_sizes_2, output_size_2)
    
    # Display the second model summary
    mlp_model2.summary()
    print("\n\n\n")

    # Concatenate the outputs of the two models
    combined_output = layers.concatenate([mlp_model1.output, mlp_model2.output])
    
    # Define a new model that takes the concatenated output as input
    merged_model = tf.keras.Model(inputs=[mlp_model1.input, mlp_model2.input], outputs=combined_output)
    
    # Display the summary of the merged model
    merged_model.summary()
# Out:
# Model: "sequential_24"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_66 (Dense)            (None, 64)                704
#
#  dense_67 (Dense)            (None, 32)                2080
#
#  dense_68 (Dense)            (None, 2)                 66
#
# ...
# Total params: 2850 (11.13 KB)
# Trainable params: 2850 (11.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
#
#
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_69 (Dense)            (None, 74)                1554
#
#  dense_70 (Dense)            (None, 52)                3900
#
#  dense_71 (Dense)            (None, 2)                 106
#
# ...
# Total params: 5560 (21.72 KB)
# Trainable params: 5560 (21.72 KB)
# Non-trainable params: 0 (0.00 Byte)
# ...
